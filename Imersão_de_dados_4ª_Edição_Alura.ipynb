# %% [markdown]
# ### **Imersão de dados - 4ª Edição - Alura**

# %% [markdown]
# ![Slide1.jpg](data:image/jpeg;base64,...)

# %%
import pandas as pd
url = "https://gist.githubusercontent.com/tgcsantos/3bdb29eba6ce391e90df2b72205ba891/raw/22fa920e80c9fa209a9fccc8b52d74cc95d1599b/dados_imoveis.csv"
dados = pd.read_csv(url)
dados.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor
# 0        4          8      6  R$ 7.000.000
# 1        4          4      4  R$ 3.700.000
# 2        4          3      2    R$ 380.000
# 3        3          2      4    R$ 685.000
# 4        3          2      2    R$ 540.000

# %%
dados.sample(10)
# Out:
#                              Rua              Bairro     Cidade  Metragem  \
# 9628  Rua Almirante Soares Dutra             Morumbi  São Paulo       504
# 913                          NaN      Jardim Everest  São Paulo       711
# 6715          Rua Granja Julieta      Granja Julieta  São Paulo       225
# 9112       Rua Laurindo Sbampato      Vila Guilherme  São Paulo        80
# 191                          NaN             Morumbi  São Paulo      1800
# 4137        Avenida Indianópolis        Indianópolis  São Paulo       200
# 9584                  Rua Kansas   Brooklin Paulista  São Paulo       100
# 3359        Rua Lomas Valentinas        Alto da Lapa  São Paulo       380
# 9247             Rua Barra Negra       Vila Oratório  São Paulo       158
# 3521              Rua Itapacurai  Paraíso do Morumbi  São Paulo       240
#
#       Quartos  Banheiros  Vagas                                  Valor
# 9628        4          8      5                           R$ 3.800.000
# 913         4          5      3                           R$ 3.500.000
# 6715        4          4      4                           R$ 1.600.000
# 9112        2          1      2                             R$ 470.000
# 191         3          5      6  R$ 80.000\n                      /Mês
# 4137        3          2      2   R$ 8.000\n                      /Mês
# 9584        2          4      2                             R$ 800.000
# 3359        3          4      4                           R$ 2.850.000
# 9247        3          3      6                           R$ 1.330.000
# 3521        3          3      8                             R$ 850.000

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10008 entries, 0 to 10007
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Rua        6574 non-null   object
#  1   Bairro     9996 non-null   object
#  2   Cidade     10008 non-null  object
#  3   Metragem   10008 non-null  int64
#  4   Quartos    10008 non-null  int64
#  5   Banheiros  10008 non-null  int64
#  6   Vagas      10008 non-null  int64
#  7   Valor      10008 non-null  object
# dtypes: int64(4), object(4)
# memory usage: 625.6+ KB

# %%
dados ["Bairro"] [6522]
# Out:
# 'Vila Paulo Silas'

# %%
dados.Metragem.mean()
# Out:
# 442.30065947242207

# %%
dados["Metragem"].mean()
# Out:
# 442.30065947242207

# %%
sum((dados["Bairro"] == "Vila Mariana"))
# Out:
# 184

# %%
tem_imoveis_vila = (dados["Bairro"] == "Vila Mariana")
tem_imoveis_vila
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10003    False
# 10004    False
# 10005    False
# 10006    False
# 10007    False
# Name: Bairro, Length: 10008, dtype: bool

# %%
imoveis_vila_mariana = dados[tem_imoveis_vila]
imoveis_vila_mariana
# Out:
#                                Rua        Bairro     Cidade  Metragem  \
# 100               Rua Pero Correia  Vila Mariana  São Paulo       250
# 120   Praça Doutor Carvalho Franco  Vila Mariana  São Paulo       250
# 155     Rua Professor João Marinho  Vila Mariana  São Paulo       170
# 160                            NaN  Vila Mariana  São Paulo       228
# 334         Rua Pero Correia, 892   Vila Mariana  São Paulo       350
# ...                            ...           ...        ...       ...
# 9645               Rua Sousa Ramos  Vila Mariana  São Paulo       285
# 9701             Rua Benito Juarez  Vila Mariana  São Paulo       171
# 9737             Rua Benito Juarez  Vila Mariana  São Paulo       171
# 9807                           NaN  Vila Mariana  São Paulo       275
# 9852              Rua França Pinto  Vila Mariana  São Paulo       280
#
#       Quartos  Banheiros  Vagas         Valor
# 100         3          3      1  R$ 1.350.000
# 120         3          5      2  R$ 2.450.000
# 155         3          4      2  R$ 1.490.000
# 160         4          5      3  R$ 2.200.000
# 334         6          4     10  R$ 1.700.000
# ...       ...        ...    ...           ...
# 9645        3          5      5  R$ 1.650.000
# 9701        3          2      4  R$ 1.650.000
# 9737        3          2      4  R$ 1.650.000
# 9807        3          1      6  R$ 1.500.000
# 9852        3          3      4  R$ 1.600.000
#
# [184 rows x 8 columns]

# %%
imoveis_vila_mariana ["Metragem"].mean()
# Out:
# 233.6195652173913

# %%
dados ["Bairro"].value_counts()
# Out:
# Alto de Pinheiros     409
# Jardim Guedala        403
# Jardim Paulista       309
# Brooklin Paulista     247
# Jardim Europa         240
#                      ...
# Jardim das Imbuias      1
# Vila Represa            1
# Vila Nancy              1
# Sítio Represa           1
# Vila Invernada          1
# Name: Bairro, Length: 701, dtype: int64

# %%
n_imoveis_bairro = dados ["Bairro"].value_counts()
n_imoveis_bairro.head(10).plot.bar()

# %% [markdown]
# ### **Desafios - Aula 1**

# %% [markdown]
# 1.   Realizar a média da metragem para cada um dos bairros. (Paulo);
# 2.   Indicar duas formas de selecionar os dados por bairro. Caso haja dúvida, consultar os métodos de documentação do Pandas. (Thiago);
# 3.   Explorar alguns gráficos na documentação do Pandas e aplicar nas demais colunas do DF, buscando alguma conclusão (Thiago);
# 4.   Informar outros dados presentes no database, tais como a mediana, a média, a mínima e a máxima (Vivian);
# 5.   Informar quais são os bairros que não possuem os nomes de rua (Vivian);

# %% [markdown]
# ## Desafio 1 - Realizar a média da metragem para cada um dos bairros

# %%
media_metragem_bairros = dados.groupby('Bairro')['Metragem'].mean();
media_metragem_bairros
# Out:
# Bairro
# Aclimação           253.06
# Alto da Boa Vista   418.88
# Alto da Lapa        294.34
# Alto da Mooca       270.05
# Alto de Pinheiros   433.44
#                      ...
# Vila Água Funda     152.20
# Água Branca         191.00
# Água Fria           165.42
# Água Funda          139.00
# Água Rasa           340.25
# Name: Metragem, Length: 701, dtype: float64

# %% [markdown]
# ## Desafio 2 - Indicar duas formas de selecionar os dados por bairro.

# %% [markdown]
# **Forma 1**: *Localizando um imóvel aleatoriamente no Bairro Jardim Europa utilizando a fórmula sample(), cujo foco é a amostragem aleatória sem reposição.*

# %%
dados[dados["Bairro"] == 'Jardim Europa'].sample()
# Out:
#       Rua         Bairro     Cidade  Metragem  Quartos  Banheiros  Vagas  \
# 3849  NaN  Jardim Europa  São Paulo       559        4          4      4
#
#                                       Valor
# 3849  R$ 45.000\n                      /Mês

# %% [markdown]
# *Solução encontrada graças aos excertos de @fmcamargo (https://github.com/fmcamargo/alura-imersaoDados/blob/8be6bbd44a0c2973794c29930b54fe36e8f13b25/Imersão_Dados_Alura.ipynb)*

# %% [markdown]
# **Forma 2**: *Utilizando o Query, que nada mais é do que um método de consulta ao banco de dados ofertado neste exercício*.

# %%
dados.query(" Bairro == 'Brooklin Paulista'")
# Out:
#                                          Rua             Bairro     Cidade  \
# 50                                Rua Kansas  Brooklin Paulista  São Paulo
# 104                                      NaN  Brooklin Paulista  São Paulo
# 122                        Rua Kansas, 1326   Brooklin Paulista  São Paulo
# 135                              Rua Laplace  Brooklin Paulista  São Paulo
# 284                               Rua Kansas  Brooklin Paulista  São Paulo
# ...                                      ...                ...        ...
# 9950                           Rua Luisiania  Brooklin Paulista  São Paulo
# 9952                     Rua Princesa Isabel  Brooklin Paulista  São Paulo
# 9978  Rua Professor Miguel Maurício da Rocha  Brooklin Paulista  São Paulo
# 9986                           Rua Luisiania  Brooklin Paulista  São Paulo
# 9988                     Rua Princesa Isabel  Brooklin Paulista  São Paulo
#
#       Metragem  Quartos  Banheiros  Vagas         Valor
# 50         180        3          3      3  R$ 1.100.000
# 104        400        5          6      4  R$ 2.500.000
# 122         70        2          4      2    R$ 800.000
# 135        300        3          5      4  R$ 2.400.000
# 284        200        3          1     10  R$ 2.240.000
# ...        ...      ...        ...    ...           ...
# 9950       205        3          1      3  R$ 2.200.000
# 9952       170        3          3      2  R$ 1.250.000
# 9978       874        3          1      7  R$ 5.500.000
# 9986       205        3          1      3  R$ 2.200.000
# 9988       170        3          3      2  R$ 1.250.000
#
# [247 rows x 8 columns]

# %% [markdown]
# *Solução encontrada graças aos excertos de @IzabellaJastrow (https://github.com/IzabellaJastrow/ImersaoDadosAlura/blob/main/aula_1.ipynb)*

# %% [markdown]
# ## Desafio 3 - Explorar alguns gráficos na documentação do Pandas e aplicar nas demais colunas do DF, buscando alguma conclusão

# %% [markdown]
# **Conclusão 1**: *Os 10 bairros com maior quantidade de imóveis com endereço são, respectivamente*:
#
#
# 1.   *Alto de Pinheiros*;
# 2.   *Jardim Guedala*;
# 3.   *Brooklin Paulista*;
# 4.   *Jardim Paulista*;
# 5.   *Vila Mariana*;
# 6.   *Pacaembu*;
# 7.   *Planalto Paulista*;
# 8.   *Vila Madalena*;
# 9.   *Cidade Jardim*;
# 10.   *Campo Belo*;

# %%
imoveis_com_endereco = dados[dados["Rua"].notna()]
imoveis_com_endereco["Bairro"].value_counts().head(10).plot.barh()

# %% [markdown]
# *Solução encontrada graças aos excertos de @andrerojr (https://github.com/anderojr/imersao_dados_4/blob/main/Imersão_Dados_4_Pesquisa_de_Imóveis.ipynb)*

# %% [markdown]
# **Conclusão 2** - *O bairro que apresenta o imóvel com a maior metragem é o Sítio Represa.*

# %%
dados.groupby(['Bairro'])['Metragem'].mean().sort_values(ascending=False).head().plot()

# %%
total_imoveis_sitiorepresa = sum((dados.Bairro == "Sítio Represa"));
total_imoveis_sitiorepresa
# Out:
# 1

# %% [markdown]
# *Como o Bairro Sítio Represa apresenta apenas um imóvel com 37.000 m² (trinta e sete mil metros quadrados), esta amostra pode ser considerada um outlier. Portanto cabe ao intérprete de dados acerca de sua pertinência e relevância*.

# %% [markdown]
# *Solução encontrada graças aos excertos de @danielfeloiola (https://github.com/danielfeloiola/alura-imersao-dados/blob/main/alura_imersao_aula_1.ipynb) e @nanipumpkin (https://github.com/nanipumpkin/imersao_alura/blob/main/imersao_4_pesq_imoveis.ipynb)*.

# %% [markdown]
# ## Desafio 4 - Informar outros dados presentes no database, tais como a mediana, a média, a mínima e a máxima.

# %%
dados_numericos = dados[["Metragem", "Quartos", "Banheiros", "Vagas"]]

dados_media = round(dados_numericos.mean(), 1)
dados_mediana = dados_numericos.median()
dados_min = dados_numericos.min()
dados_max = dados_numericos.max()

# %%
calculos = {"Média" : dados_media, "Mediana" : dados_mediana, "Mínimo" : dados_min, "Máximo" : dados_max}
estatisticas = pd.DataFrame(calculos)
estatisticas
# Out:
#            Média  Mediana  Mínimo  Máximo
# Metragem  442.30   290.00      10  750000
# Quartos     3.50     3.00       1      16
# Banheiros   3.90     4.00       1      40
# Vagas       4.10     4.00       1      50

# %% [markdown]
# *Solução encontrada graças aos excertos de @andrerojr (https://github.com/anderojr/imersao_dados_4/blob/main/Imersão_Dados_4_Pesquisa_de_Imóveis.ipynb)*

# %% [markdown]
# ## Desafio 5 - Informar quais são os bairros que não possuem os nomes de rua

# %% [markdown]
# Conforme o dataset, existem 3430 (três mil, quatrocentos e trinta) ruas sem nome no banco de dados.

# %%
rua_sem_nome = dados[dados['Rua'].isna()];

# %%
rua_sem_nome['Bairro']
# Out:
# 3                         Jardim Morumbi
# 11                      Jardim Luzitânia
# 31                        Parque da Lapa
# 56      Chácara Santo Antônio (Zona Sul)
# 57                        Jardim Guedala
#                       ...
# 9963                   Jardim Petrópolis
# 9989                Parque Alves de Lima
# 9991                        Vila Formosa
# 9995                       Jardim Leonor
# 9999                   Jardim Petrópolis
# Name: Bairro, Length: 3434, dtype: object

# %% [markdown]
# Estas 3430 ruas sem nome se encontram distribuidas em 12 bairros distintos.

# %%
dados.isnull().sum()
# Out:
# Rua          3434
# Bairro         12
# Cidade          0
# Metragem        0
# Quartos         0
# Banheiros       0
# Vagas           0
# Valor           0
# dtype: int64

# %% [markdown]
# Os 5 bairros que apresentam o maior número de ruas sem nome são:
#
#
# 1.   Jardim Guedala;
# 2.   Alto de Pinheiros;
# 2.   Jardim Paulista;
# 2.   Jardim Europa;
# 2.   Jardim Leonor.

# %%
bairro_sem_nome_rua = dados['Rua'].isnull()
bairro_sem_nome_rua = dados['Bairro'][bairro_sem_nome_rua].value_counts()
bairro_sem_nome_rua= pd.DataFrame(bairro_sem_nome_rua)
bairro_sem_nome_rua
# Out:
#                                   Bairro
# Jardim Guedala                       190
# Alto de Pinheiros                    169
# Jardim Paulista                      138
# Jardim Europa                        128
# Jardim Leonor                        118
# ...                                  ...
# Jardim do Colégio (Zona Norte)         1
# Alto da Boa Vista                      1
# Jardim Aeroporto                       1
# Conjunto Residencial Vista Verde       1
# Jardim Santo Elias                     1
#
# [394 rows x 1 columns]

# %% [markdown]
# *Solução encontrada graças aos excertos de @rafaellagp (https://github.com/rafaellagp/Alura/blob/main/alura_imersao_dados_Aula1_Desafios_RGP.ipynb) e @eduardozim (https://github.com/eduardozim/Data_science/blob/main/Imersão_de_dados_4_Alura.ipynb)"*.

# %% [markdown]
# # **Aula 2 - Imersão de dados**

# %%
dados.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor
# 0        4          8      6  R$ 7.000.000
# 1        4          4      4  R$ 3.700.000
# 2        4          3      2    R$ 380.000
# 3        3          2      4    R$ 685.000
# 4        3          2      2    R$ 540.000

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10008 entries, 0 to 10007
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Rua        6574 non-null   object
#  1   Bairro     9996 non-null   object
#  2   Cidade     10008 non-null  object
#  3   Metragem   10008 non-null  int64
#  4   Quartos    10008 non-null  int64
#  5   Banheiros  10008 non-null  int64
#  6   Vagas      10008 non-null  int64
#  7   Valor      10008 non-null  object
# dtypes: int64(4), object(4)
# memory usage: 625.6+ KB

# %%
dados["Valor"] [0]
# Out:
# 'R$ 7.000.000'

# %% [markdown]
# *Criando arrays*

# %%
dados["Valor"] [0].split()
# Out:
# ['R$', '7.000.000']

# %%
dados.sample(10)
# Out:
#                                 Rua                     Bairro     Cidade  \
# 5828       Rua Nelson Lins e Barros  Jardim Vergueiro (Sacomã)  São Paulo
# 6461           Rua Barão do Triunfo          Brooklin Paulista  São Paulo
# 3824  Rua Engenheiro Lauro Penteado             Vila Monumento  São Paulo
# 3508                            NaN             Jardim Guedala  São Paulo
# 1557                            NaN              Vila Madalena  São Paulo
# 7669          Rua Wanderley, , 369                    Perdizes  São Paulo
# 4463                   Rua Pamplona            Jardim Paulista  São Paulo
# 3158                 Rua Conde D'Eu                Santo Amaro  São Paulo
# 1236              Rua Mário de Melo                   Pacaembu  São Paulo
# 2794                            NaN                   Tucuruvi  São Paulo
#
#       Metragem  Quartos  Banheiros  Vagas         Valor
# 5828       120        4          2      1    R$ 500.000
# 6461       220        3          4      2  R$ 1.910.000
# 3824       160        3          4      3  R$ 2.500.000
# 3508       542        4          4      6  R$ 4.200.000
# 1557       467        6          6      3  R$ 3.300.000
# 7669       135        2          2      1    R$ 900.000
# 4463       161        4          4      2  R$ 2.340.000
# 3158       756        5          6      5  R$ 3.800.000
# 1236       420        4          2      5  R$ 3.000.000
# 2794        90        3          2      1    R$ 490.000

# %% [markdown]
# *Criando colunas para cada uma das variáveis geradas pelo database*

# %%
dados["Valor"].str.split(expand = True)
# Out:
#         0          1     2
# 0      R$  7.000.000  None
# 1      R$  3.700.000  None
# 2      R$    380.000  None
# 3      R$    685.000  None
# 4      R$    540.000  None
# ...    ..        ...   ...
# 10003  R$    665.000  None
# 10004  R$  2.300.000  None
# 10005  R$  1.050.000  None
# 10006  R$      2.200  /Mês
# 10007  R$    270.000  None
#
# [10008 rows x 3 columns]

# %% [markdown]
# *Deste modo foram criados dataframes com cada elemento da separação (apenas três elementos separados por dataframes).*

# %% [markdown]
# *O tratamento de dados acabou exigindo a necessidade de descobrir se todos os elementos da coluna 0 contêm, de fato, somente (R$)*:

# %%
dados["Valor"].str.split(expand = True)[0].unique()
# Out:
# array(['R$'], dtype=object)

# %% [markdown]
# *Por sorte não havia outro dado na coluna 0 senão o cifrão desejado (R$), o que a tornou limpa.*

# %% [markdown]
# *É possível também descobrir quantos valores (preços) existem na coluna 1:*
# *Obs. len marca a extensão da array.*

# %%
len(dados["Valor"].str.split(expand = True)[1].unique())
# Out:
# 1038

# %% [markdown]
# *Existem, portanto, 10.008 linhas com somente 1038 preços, o que significa dizer que há muitos preços iguais/repetidos.*

# %%
dados["Valor"].str.split(expand = True)[2].unique()
# Out:
# array([None, '/Mês', '/Ano', '/Dia'], dtype=object)

# %% [markdown]
# *Repetida a função de análise da coluna 0 para a coluna 2, percebe-se que nesta existem as informações de mês, ano e dia. Isto quer dizer que, provalvelmente, há dados de venda e dados de aluguel.*
# *Precisamos agora migrar os dados do split para o dataframe:*

# %%
dados [["Moeda", "Valor_anuncio", "Tipo_anuncio"]] = dados["Valor"].str.split(expand = True)
dados.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor Moeda Valor_anuncio Tipo_anuncio
# 0        4          8      6  R$ 7.000.000    R$     7.000.000         None
# 1        4          4      4  R$ 3.700.000    R$     3.700.000         None
# 2        4          3      2    R$ 380.000    R$       380.000         None
# 3        3          2      4    R$ 685.000    R$       685.000         None
# 4        3          2      2    R$ 540.000    R$       540.000         None

# %% [markdown]
# *É possível selecionar uma única coluna (ex. Valor), bem como selecionar mais de uma coluna. Será necessário passar uma lista com o nome de cada coluna que se deseja manipular.*

# %% [markdown]
# *Deste modo, para continuar o tratamento de dados, será necessário eliminar todo tipo de anúncio que não está vazio:*

# %%
dados[dados["Tipo_anuncio"].isnull()]["Tipo_anuncio"].unique()
# Out:
# array([None], dtype=object)

# %% [markdown]
# *Assim, se percebe a existência de um array vazio - o que demonstra que o pretendido deu certo.*

# %%
dados_vendas = dados[dados["Tipo_anuncio"].isnull()]
dados_vendas
# Out:
#                                   Rua              Bairro     Cidade  \
# 0               Avenida Itacira, 255    Planalto Paulista  São Paulo
# 1      Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo
# 2                     Rua Alba Valdez     Jardim Reimberg  São Paulo
# 3                                 NaN      Jardim Morumbi  São Paulo
# 4            Rua Tobias Barreto, 195                Mooca  São Paulo
# ...                               ...                 ...        ...
# 10002                   Avenida Odila   Planalto Paulista  São Paulo
# 10003                      Rua Tapuçu          Vila Sofia  São Paulo
# 10004                   Rua Guararema     Bosque da Saúde  São Paulo
# 10005               Rua Estero Belaco       Vila da Saúde  São Paulo
# 10007      Rua Barão de Tramandaí, 0          Vila Alpina  São Paulo
#
#        Metragem  Quartos  Banheiros  Vagas         Valor Moeda Valor_anuncio  \
# 0          1000        4          8      6  R$ 7.000.000    R$     7.000.000
# 1           496        4          4      4  R$ 3.700.000    R$     3.700.000
# 2           125        4          3      2    R$ 380.000    R$       380.000
# 3           310        3          2      4    R$ 685.000    R$       685.000
# 4           100        3          2      2    R$ 540.000    R$       540.000
# ...         ...      ...        ...    ...           ...   ...           ...
# 10002       267        3          6      4  R$ 1.500.000    R$     1.500.000
# 10003        95        2          2      2    R$ 665.000    R$       665.000
# 10004       605        8          7      5  R$ 2.300.000    R$     2.300.000
# 10005       205        3          3      6  R$ 1.050.000    R$     1.050.000
# 10007       122        3          2      2    R$ 270.000    R$       270.000
#
#       Tipo_anuncio
# 0             None
# 1             None
# 2             None
# 3             None
# 4             None
# ...            ...
# 10002         None
# 10003         None
# 10004         None
# 10005         None
# 10007         None
#
# [9156 rows x 11 columns]

# %% [markdown]
# *Após a análise, restou evidente que há somente 9.159 imóveis disponíveis para venda. Estão excluídas as locações e afins.*

# %% [markdown]
# *Agora é preciso transformar o "valor_anuncio" em números.*

# %%
dados_vendas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9156 entries, 0 to 10007
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rua            6107 non-null   object
#  1   Bairro         9146 non-null   object
#  2   Cidade         9156 non-null   object
#  3   Metragem       9156 non-null   int64
#  4   Quartos        9156 non-null   int64
#  5   Banheiros      9156 non-null   int64
#  6   Vagas          9156 non-null   int64
#  7   Valor          9156 non-null   object
#  8   Moeda          9156 non-null   object
#  9   Valor_anuncio  9156 non-null   object
#  10  Tipo_anuncio   0 non-null      object
# dtypes: int64(4), object(7)
# memory usage: 858.4+ KB

# %%
dados_vendas["Valor_anuncio"].str.replace(".","").astype(float)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   """Entry point for launching an IPython kernel.
# 0       7000000.00
# 1       3700000.00
# 2        380000.00
# 3        685000.00
# 4        540000.00
#            ...
# 10002   1500000.00
# 10003    665000.00
# 10004   2300000.00
# 10005   1050000.00
# 10007    270000.00
# Name: Valor_anuncio, Length: 9156, dtype: float64

# %%
dados_vendas["Valor_anuncio_float"] = dados_vendas["Valor_anuncio"].str.replace(".","").astype(float)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dados_vendas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9156 entries, 0 to 10007
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Rua                  6107 non-null   object
#  1   Bairro               9146 non-null   object
#  2   Cidade               9156 non-null   object
#  3   Metragem             9156 non-null   int64
#  4   Quartos              9156 non-null   int64
#  5   Banheiros            9156 non-null   int64
#  6   Vagas                9156 non-null   int64
#  7   Valor                9156 non-null   object
#  8   Moeda                9156 non-null   object
#  9   Valor_anuncio        9156 non-null   object
#  10  Tipo_anuncio         0 non-null      object
#  11  Valor_anuncio_float  9156 non-null   float64
# dtypes: float64(1), int64(4), object(7)
# memory usage: 929.9+ KB

# %%
dados_vendas["Valor_anuncio_float"].plot.hist(bins = 50)

# %%
pd.set_option("display.precision", 2)
pd.set_option("display.float_format", lambda x: "%.2f" % x)
dados_vendas.describe(include = "all")
# Out:
#                       Rua             Bairro     Cidade  Metragem  Quartos  \
# count                6107               9146       9156   9156.00  9156.00
# unique               3006                697          1       NaN      NaN
# top     Rua Alberto Faria  Alto de Pinheiros  São Paulo       NaN      NaN
# freq                   24                369       9156       NaN      NaN
# mean                  NaN                NaN        NaN    434.42     3.45
# std                   NaN                NaN        NaN   7856.42     1.05
# min                   NaN                NaN        NaN     10.00     1.00
# 25%                   NaN                NaN        NaN    168.00     3.00
# 50%                   NaN                NaN        NaN    276.00     3.00
# 75%                   NaN                NaN        NaN    450.00     4.00
# max                   NaN                NaN        NaN 750000.00    16.00
#
#         Banheiros   Vagas         Valor Moeda Valor_anuncio Tipo_anuncio  \
# count     9156.00 9156.00          9156  9156          9156            0
# unique        NaN     NaN           939     1           939            0
# top           NaN     NaN  R$ 2.500.000    R$     2.500.000          NaN
# freq          NaN     NaN           182  9156           182          NaN
# mean         3.80    3.96           NaN   NaN           NaN          NaN
# std          1.97    2.60           NaN   NaN           NaN          NaN
# min          1.00    1.00           NaN   NaN           NaN          NaN
# 25%          2.00    2.00           NaN   NaN           NaN          NaN
# 50%          4.00    4.00           NaN   NaN           NaN          NaN
# 75%          5.00    5.00           NaN   NaN           NaN          NaN
# max         40.00   50.00           NaN   NaN           NaN          NaN
#
#         Valor_anuncio_float
# count               9156.00
# unique                  NaN
# top                     NaN
# freq                    NaN
# mean             3052202.96
# std              3944208.19
# min                13000.00
# 25%               890000.00
# 50%              1800000.00
# 75%              3500000.00
# max             65000000.00

# %%
dados_vendas[["Rua","Bairro","Cidade"]].describe()
# Out:
#                       Rua             Bairro     Cidade
# count                6107               9146       9156
# unique               3006                697          1
# top     Rua Alberto Faria  Alto de Pinheiros  São Paulo
# freq                   24                369       9156

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set()
plt. figure(figsize=(10,8))
ax = sns.histplot(data = dados_vendas, x = "Valor_anuncio_float", kde = True)
ax.set_title ("Histograma Valor Imóvel")
plt.xlim((-50, 10000000))
plt.show()

# %% [markdown]
# # **DESAFIOS AULA 2**
#
# 1. Criar uma escala de valores em milhões (Thiago);
# 2. Deixar o gráfico de histograma de valores mais legível, alterando as labels, títulos, escalas e cores para facilitar o suporte de decisão (Paulo);
# 3.   Informar o preço do metro quadrado por bairro na cidade de São Paulo (Paulo);
# 4. Demonstrar o preço do metro quadrado por bairro em um gráfico (Paulo);
# 5. Explorar bibliotecas buscando combinar duas ou mais variáveis numéricas, apresentando textos explicativos para desmistificar o conteúdo exposto (Vivian);
# 6. Pesquisar uma visualização para analisar os quartis, mediana e outliers (Thiago);

# %% [markdown]
# # **Desafios 1 e 2 - Criar uma escala de valores em milhões, deixando o gráfico de histograma de valores mais legível, alterando as labels, títulos, escalas e cores para facilitar o suporte de decisão**

# %%
plt.figure(figsize = (15, 8))
ax = sns.histplot(data = dados_vendas, x = "Valor_anuncio_float", kde = True, ec = "black", color = "black")
ax.set_title("Valor de Venda dos imóveis em São Paulo", pad = 22, fontsize = 22)
plt.xlabel("Valor do Imóvel (Milhões)")
plt.ylabel("Quantidade de Imóveis")
plt.xticks([0, 1000000, 20000000, 3000000, 4000000, 5000000, 6000000, 7000000, 8000000, 9000000], rotation=0)
plt.xlim((-50, 10000000))
plt.show()

# %%
dados_milhoes = dados_vendas["Valor_anuncio_float"] / 1000000
dados_milhoes
# Out:
# 0       7.00
# 1       3.70
# 2       0.38
# 3       0.69
# 4       0.54
#         ...
# 10002   1.50
# 10003   0.67
# 10004   2.30
# 10005   1.05
# 10007   0.27
# Name: Valor_anuncio_float, Length: 9156, dtype: float64

# %% [markdown]
# *Solução encontrada graças aos excertos de @fernandovicentinpavanello (https://github.com/fernandovicentinpavanello/imersao_dados_4_Alura/blob/main/Aula_02/aula_02.ipynb)*

# %% [markdown]
# # **Desafios 3 e 4 - Informar o preço do metro quadrado por bairro na cidade de São Paulo, demonstrando-os em gráficos.**

# %%
valores_bairro = dados_vendas.groupby('Bairro')['Valor_anuncio_float'].sum()
metragem_bairro = dados_vendas.groupby('Bairro')['Metragem'].sum()

valor_m2_2 = valores_bairro/metragem_bairro
valor_m2_2 = valor_m2_2.sort_values(ascending=False)
plt.figure(figsize=(15, 8))
valor_m2_2[:30].plot(kind='bar', ec = "black", color = "grey")

plt.title('Valor do m² dos trinta bairros mais caros de São Paulo', pad = 22, fontsize = 22)
plt.ylabel('Valor do m² em reais')
plt.show()

# %% [markdown]
# *A fim de facilitar o entendimento, visto que existem muitos bairros no nosso dataset, fora calculado o preço do metro quadrado dos trinta bairros mais caros de São Paulo. Após a conclusão da análise de dados, percebe-se que o imovel existente no bairro Vila Guaca é um exemplo de outlier, uma vez que o valor de seu m² é discrepante face o restante dos bairros.
# Após a filtragem minuciosa deste outlier, nota-se a existência de somente um imóvel nesta localidade, apresentando os seguintes dados:*

# %%
dados_vendas[dados_vendas['Bairro'] == 'Vila Guaca']
# Out:
#               Rua      Bairro     Cidade  Metragem  Quartos  Banheiros  Vagas  \
# 9603  Rua Pestana  Vila Guaca  São Paulo        10        3          2      2
#
#            Valor Moeda Valor_anuncio Tipo_anuncio  Valor_anuncio_float
# 9603  R$ 800.000    R$       800.000         None            800000.00

# %% [markdown]
# *Este imóvel apresenta a pífia metragem de apenas 10m², supostamente contendo 3 quartos, 2 banheiros e 2 vagas de garagem. Além disso, está sendo anunciado pelo valor total de oitocentos mil reais, gerando o valor absurdo de oitenta mil reais por m². Isto posto, resta evidente a incongruência de dados, fato que gera a distorção apresentada no gráfico.*

# %% [markdown]
# *Solução encontrada graças aos excertos de @iagomachado (https://github.com/iagomachadoeng/Imersao_Dados_Alura_04/blob/master/Imersao_dados_4_aula02.ipynb)*

# %% [markdown]
# # **Desafio 5 - Explorar bibliotecas buscando combinar duas ou mais variáveis numéricas, apresentando textos explicativos para desmistificar o conteúdo exposto.**

# %% [markdown]
# **Distribuição da média de quartos em Imóveis em São Paulo**

# %%
plt.figure(figsize=(15, 8))
dados_vendas['Quartos'].plot(kind = 'hist', bins = 100)
plt.title('Distribuição da média de quartos em Imóveis de São Paulo')
plt.xlabel('Quantidade de Quartos')
plt.ylabel('Quantidade de imóveis')
plt.show()

# %% [markdown]
# **Distribuição da média de banheiros em Imóveis em São Paulo**

# %%
plt.figure(figsize=(15, 8))
dados_vendas['Banheiros'].plot(kind = 'hist', bins = 100)
plt.title('Distribuição da média de banheiros em Imóveis de São Paulo')
plt.xlabel('Quantidade de banheiros')
plt.ylabel('Quantidade de imóveis')
plt.show()

# %% [markdown]
# **Relação entre quantidade de quartos e quantidade de banheiros em imóveis de São Paulo**

# %%
plt.figure(figsize=(10,7))

data_small = dados_vendas[:200]
sns.histplot(data_small, x="Quartos", y="Banheiros")

plt.show()

# %% [markdown]
# Tomando como base as conclusões obtidas nos desafios 3, 4 e 5, é possivel emitir as seguintes afirmações:
#
# 1.   O imovel existente no bairro Vila Guaca é um exemplo de outlier, uma vez que o valor de seu m² é discrepante do restante dos bairros;
# 2.   Afastado o outlier, os cinco bairros de São Paulo que apresentam o m² mais caro são, respectivamente, o Jardim América, o Jardim Teresa, o Jardim Europa, a Vila Nova Conceição e o Morro dos Ingleses;
# 3. A quantidade de quartos mais frequente nos imóveis do dataset é de 3 por imóvel;
# 4. A quantidade de banheiros mais frequente nos imóveis do dataset é de 3 por imóvel;
# 5. Os imóveis com maior número de quartos tende a apresentar um maior número de banheiros.

# %% [markdown]
# *Solução encontrada graças aos excertos de @fernandovicentinpavanello (https://github.com/fernandovicentinpavanello/imersao_dados_4_Alura/blob/main/Aula_02/aula_02.ipynb), @iagomachado (https://github.com/iagomachadoeng/Imersao_Dados_Alura_04/blob/master/Imersao_dados_4_aula02.ipynb) e @brenomfviana (https://github.com/brenov/imersao-dados-alura/blob/main/Imersão%20de%20Dados%204%20-%20Alura%20-%20Desafios%20Dia%202.ipynb)*

# %% [markdown]
# # **Desafio 6 - Pesquisar uma visualização para analisar os quartis, mediana e outliers.**

# %%
dados_vendas.describe()
# Out:
#        Metragem  Quartos  Banheiros   Vagas  Valor_anuncio_float
# count   9156.00  9156.00    9156.00 9156.00              9156.00
# mean     434.42     3.45       3.80    3.96           3052202.96
# std     7856.42     1.05       1.97    2.60           3944208.19
# min       10.00     1.00       1.00    1.00             13000.00
# 25%      168.00     3.00       2.00    2.00            890000.00
# 50%      276.00     3.00       4.00    4.00           1800000.00
# 75%      450.00     4.00       5.00    5.00           3500000.00
# max   750000.00    16.00      40.00   50.00          65000000.00

# %%
plt.figure(figsize=(18, 8))
sns.boxplot(data=dados_vendas[["Banheiros", "Quartos"]], x="Banheiros", y="Quartos")
plt.title('Boxplot')
plt.xlabel('Banheiros')
plt.ylabel('Quartos')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# *Solução encontrada graças aos excertos de @fernandovicentinpavanello (https://github.com/fernandovicentinpavanello/imersao_dados_4_Alura/blob/main/Aula_02/aula_02.ipynb)*

# %% [markdown]
# # **Aula 3 - Imersão de dados**

# %%
dados_vendas.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor Moeda Valor_anuncio Tipo_anuncio  \
# 0        4          8      6  R$ 7.000.000    R$     7.000.000         None
# 1        4          4      4  R$ 3.700.000    R$     3.700.000         None
# 2        4          3      2    R$ 380.000    R$       380.000         None
# 3        3          2      4    R$ 685.000    R$       685.000         None
# 4        3          2      2    R$ 540.000    R$       540.000         None
#
#    Valor_anuncio_float
# 0           7000000.00
# 1           3700000.00
# 2            380000.00
# 3            685000.00
# 4            540000.00

# %% [markdown]
# Cálculo do metro quadrado dos imóveis

# %%
dados_vendas["Valor_m2"] = dados_vendas["Valor_anuncio_float"]/dados_vendas["Metragem"]
dados_vendas.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor Moeda Valor_anuncio Tipo_anuncio  \
# 0        4          8      6  R$ 7.000.000    R$     7.000.000         None
# 1        4          4      4  R$ 3.700.000    R$     3.700.000         None
# 2        4          3      2    R$ 380.000    R$       380.000         None
# 3        3          2      4    R$ 685.000    R$       685.000         None
# 4        3          2      2    R$ 540.000    R$       540.000         None
#
#    Valor_anuncio_float  Valor_m2
# 0           7000000.00   7000.00
# 1           3700000.00   7459.68
# 2            380000.00   3040.00
# 3            685000.00   2209.68
# 4            540000.00   5400.00

# %%
dados_vendas.groupby("Bairro").mean()
# Out:
#                    Metragem  Quartos  Banheiros  Vagas  Valor_anuncio_float  \
# Bairro
# Aclimação            246.16     3.27       3.04   2.91           1763200.01
# Alto da Boa Vista    418.88     4.12       5.12   4.62           2391250.00
# Alto da Lapa         299.25     3.15       3.85   4.00           2083168.75
# Alto da Mooca        270.05     3.30       2.60   3.65           1184170.00
# Alto de Pinheiros    429.85     3.94       4.83   4.95           4782698.96
# ...                     ...      ...        ...    ...                  ...
# Vila Água Funda      152.20     2.60       2.20   2.60            652000.00
# Água Branca          173.58     3.08       3.25   2.25           1226500.00
# Água Fria            165.42     2.83       3.42   2.50            927083.33
# Água Funda           139.00     3.00       2.50   2.00            545000.00
# Água Rasa            186.17     2.67       2.00   3.67            716166.67
#
#                    Valor_m2
# Bairro
# Aclimação           7656.17
# Alto da Boa Vista   5849.57
# Alto da Lapa        7606.73
# Alto da Mooca       5691.74
# Alto de Pinheiros  11269.98
# ...                     ...
# Vila Água Funda     4467.13
# Água Branca         7269.11
# Água Fria           5841.10
# Água Funda          3876.86
# Água Rasa           4509.61
#
# [697 rows x 6 columns]

# %%
dados_bairro = dados_vendas.groupby("Bairro").sum()
dados_bairro
# Out:
#                    Metragem  Quartos  Banheiros  Vagas  Valor_anuncio_float  \
# Bairro
# Aclimação             19447      258        240    230         139292801.00
# Alto da Boa Vista      3351       33         41     37          19130000.00
# Alto da Lapa          23940      252        308    320         166653500.00
# Alto da Mooca          5401       66         52     73          23683400.00
# Alto de Pinheiros    158616     1453       1782   1827        1764815915.00
# ...                     ...      ...        ...    ...                  ...
# Vila Água Funda         761       13         11     13           3260000.00
# Água Branca            2083       37         39     27          14718000.00
# Água Fria              1985       34         41     30          11125000.00
# Água Funda              278        6          5      4           1090000.00
# Água Rasa              1117       16         12     22           4297000.00
#
#                     Valor_m2
# Bairro
# Aclimação          604837.39
# Alto da Boa Vista   46796.55
# Alto da Lapa       608538.25
# Alto da Mooca      113834.80
# Alto de Pinheiros 4158622.61
# ...                      ...
# Vila Água Funda     22335.64
# Água Branca         87229.37
# Água Fria           70093.25
# Água Funda           7753.73
# Água Rasa           27057.65
#
# [697 rows x 6 columns]

# %%
dados_bairro ["Valor_m2_bairro"] = dados_bairro["Valor_anuncio_float"]/dados_bairro["Metragem"]
dados_bairro
# Out:
#                    Metragem  Quartos  Banheiros  Vagas  Valor_anuncio_float  \
# Bairro
# Aclimação             19447      258        240    230         139292801.00
# Alto da Boa Vista      3351       33         41     37          19130000.00
# Alto da Lapa          23940      252        308    320         166653500.00
# Alto da Mooca          5401       66         52     73          23683400.00
# Alto de Pinheiros    158616     1453       1782   1827        1764815915.00
# ...                     ...      ...        ...    ...                  ...
# Vila Água Funda         761       13         11     13           3260000.00
# Água Branca            2083       37         39     27          14718000.00
# Água Fria              1985       34         41     30          11125000.00
# Água Funda              278        6          5      4           1090000.00
# Água Rasa              1117       16         12     22           4297000.00
#
#                     Valor_m2  Valor_m2_bairro
# Bairro
# Aclimação          604837.39          7162.69
# Alto da Boa Vista   46796.55          5708.74
# Alto da Lapa       608538.25          6961.30
# Alto da Mooca      113834.80          4385.00
# Alto de Pinheiros 4158622.61         11126.34
# ...                      ...              ...
# Vila Água Funda     22335.64          4283.84
# Água Branca         87229.37          7065.77
# Água Fria           70093.25          5604.53
# Água Funda           7753.73          3920.86
# Água Rasa           27057.65          3846.91
#
# [697 rows x 7 columns]

# %%
dados_vendas.groupby("Bairro").mean().loc ["Vila Mariana"]
# Out:
# Metragem                  231.24
# Quartos                     3.39
# Banheiros                   3.24
# Vagas                       2.95
# Valor_anuncio_float   1771159.76
# Valor_m2                 7913.15
# Name: Vila Mariana, dtype: float64

# %%
dados_bairro.loc["Vila Mariana"]
# Out:
# Metragem                  39079.00
# Quartos                     573.00
# Banheiros                   547.00
# Vagas                       499.00
# Valor_anuncio_float   299326000.00
# Valor_m2                1337323.16
# Valor_m2_bairro            7659.51
# Name: Vila Mariana, dtype: float64

# %%
dados_bairro["Valor_m2_bairro"]["Vila Mariana"]
# Out:
# 7659.510222881855

# %%
top_bairros = dados_vendas["Bairro"].value_counts()[:10].index

# %%
dados_bairro.reset_index(inplace = True)
dados_bairro
# Out:
#                 Bairro  Metragem  Quartos  Banheiros  Vagas  \
# 0            Aclimação     19447      258        240    230
# 1    Alto da Boa Vista      3351       33         41     37
# 2         Alto da Lapa     23940      252        308    320
# 3        Alto da Mooca      5401       66         52     73
# 4    Alto de Pinheiros    158616     1453       1782   1827
# ..                 ...       ...      ...        ...    ...
# 692    Vila Água Funda       761       13         11     13
# 693        Água Branca      2083       37         39     27
# 694          Água Fria      1985       34         41     30
# 695         Água Funda       278        6          5      4
# 696          Água Rasa      1117       16         12     22
#
#      Valor_anuncio_float   Valor_m2  Valor_m2_bairro
# 0           139292801.00  604837.39          7162.69
# 1            19130000.00   46796.55          5708.74
# 2           166653500.00  608538.25          6961.30
# 3            23683400.00  113834.80          4385.00
# 4          1764815915.00 4158622.61         11126.34
# ..                   ...        ...              ...
# 692           3260000.00   22335.64          4283.84
# 693          14718000.00   87229.37          7065.77
# 694          11125000.00   70093.25          5604.53
# 695           1090000.00    7753.73          3920.86
# 696           4297000.00   27057.65          3846.91
#
# [697 rows x 8 columns]

# %%
dados_bairro.query("Bairro in @top_bairros")
# Out:
#                 Bairro  Metragem  Quartos  Banheiros  Vagas  \
# 4    Alto de Pinheiros    158616     1453       1782   1827
# 19   Brooklin Paulista     70002      778        862    832
# 57       Cidade Jardim    132220      789       1008   1172
# 155      Jardim Europa    118898      795        993   1056
# 168     Jardim Guedala    972212     1443       2027   2161
# 187      Jardim Leonor     97141      697        941    902
# 227    Jardim Paulista    130283     1028       1231   1171
# 338           Pacaembu    100285      774        889   1028
# 396  Planalto Paulista     59250      636        768    713
# 564      Vila Madalena     66250      739        786    712
#
#      Valor_anuncio_float   Valor_m2  Valor_m2_bairro
# 4          1764815915.00 4158622.61         11126.34
# 19          475796789.00 1627341.87          6796.90
# 57         1164210900.00 1635692.98          8805.10
# 155        2414172900.00 4192164.45         20304.57
# 168        1801165587.00 2833882.79          1852.65
# 187         646326369.00 1115858.80          6653.49
# 227        2136081000.00 4279262.19         16395.70
# 338         867956500.00 1753672.28          8654.90
# 396         374907000.00 1186380.95          6327.54
# 564         583253030.00 1792770.40          8803.82

# %%
plt. figure(figsize=(10,8))
ax = sns.barplot(x="Bairro", y="Valor_m2_bairro", data=dados_bairro.query("Bairro in @top_bairros"))
ax.tick_params(axis='x', rotation=45)

# %%
plt.figure(figsize=(10,8))
ax = sns.boxplot(data = dados_vendas.query("Bairro in @top_bairros & Metragem < 30000"), x="Bairro", y="Metragem")
ax.tick_params(axis='x', rotation=45)
plt.show()

# %%
dados_vendas
# Out:
#                                   Rua              Bairro     Cidade  \
# 0               Avenida Itacira, 255    Planalto Paulista  São Paulo
# 1      Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo
# 2                     Rua Alba Valdez     Jardim Reimberg  São Paulo
# 3                                 NaN      Jardim Morumbi  São Paulo
# 4            Rua Tobias Barreto, 195                Mooca  São Paulo
# ...                               ...                 ...        ...
# 10002                   Avenida Odila   Planalto Paulista  São Paulo
# 10003                      Rua Tapuçu          Vila Sofia  São Paulo
# 10004                   Rua Guararema     Bosque da Saúde  São Paulo
# 10005               Rua Estero Belaco       Vila da Saúde  São Paulo
# 10007      Rua Barão de Tramandaí, 0          Vila Alpina  São Paulo
#
#        Metragem  Quartos  Banheiros  Vagas         Valor Moeda Valor_anuncio  \
# 0          1000        4          8      6  R$ 7.000.000    R$     7.000.000
# 1           496        4          4      4  R$ 3.700.000    R$     3.700.000
# 2           125        4          3      2    R$ 380.000    R$       380.000
# 3           310        3          2      4    R$ 685.000    R$       685.000
# 4           100        3          2      2    R$ 540.000    R$       540.000
# ...         ...      ...        ...    ...           ...   ...           ...
# 10002       267        3          6      4  R$ 1.500.000    R$     1.500.000
# 10003        95        2          2      2    R$ 665.000    R$       665.000
# 10004       605        8          7      5  R$ 2.300.000    R$     2.300.000
# 10005       205        3          3      6  R$ 1.050.000    R$     1.050.000
# 10007       122        3          2      2    R$ 270.000    R$       270.000
#
#       Tipo_anuncio  Valor_anuncio_float  Valor_m2
# 0             None           7000000.00   7000.00
# 1             None           3700000.00   7459.68
# 2             None            380000.00   3040.00
# 3             None            685000.00   2209.68
# 4             None            540000.00   5400.00
# ...            ...                  ...       ...
# 10002         None           1500000.00   5617.98
# 10003         None            665000.00   7000.00
# 10004         None           2300000.00   3801.65
# 10005         None           1050000.00   5121.95
# 10007         None            270000.00   2213.11
#
# [9156 rows x 13 columns]

# %%
ibge_url = "https://gist.githubusercontent.com/tgcsantos/85f8c7b0a2edbc3e27fcad619b37d886/raw/a4954781e6bca9cb804062a3eea0b3b84679daf4/Basico_SP1.csv"
pd.read_csv (ibge_url)
# Out:
#                                                                                                                                                Cod_setor;Cod_Grandes Regi�es;Nome_Grande_Regiao;Cod_UF;Nome_da_UF ;Cod_meso;Nome_da_meso;Cod_micro;Nome_da_micro;Cod_RM;Nome_da_RM;Cod_municipio;Nome_do_municipio;Cod_distrito;Nome_do_distrito;Cod_subdistrito;Nome_do_subdistrito;Cod_bairro;Nome_do_bairro;Situacao_setor;Tipo_setor;V001;V002;V003;V004;V005;V006;V007;V008;V009;V010;V011;V012;
# 355030801000001;3;"Regi�o Sudeste";35;"S�o Paul... 01;2 32;2091 32;8532451           78;2164 55;8673276 78;1227 41;4285771 99;1713 75;5152087                                              86.00
# 355030801000002;3;"Regi�o Sudeste";35;"S�o Paul... 98;2 09;1650 09;3983441           31;1717 44;4030519 99;1045 78;2572133 32;1468 08;2991546                                              94.00
# 355030801000003;3;"Regi�o Sudeste";35;"S�o Paul... 31;3 08;1280 43;5474593           06;2349 53;7553913 02;902  97;2735492 52;1786 79;3837674                                              74.00
# 355030801000004;3;"Regi�o Sudeste";35;"S�o Paul... 16;2 26;1119 59;3572955           1;1859  13;4567289 5;869   09;2122409 02;1567 41;2735383                                              24.00
# 355030801000005;3;"Regi�o Sudeste";35;"S�o Paul... 14;2 35;1416 9;2240207            58;1581 66;2240109 39;917  71;1570047 75;1356 35;1725877                                              85.00
# ...                                                                                                                                                                                          ...
# 355030896000243;3;"Regi�o Sudeste";35;"S�o Paul... 5;2  61;772  09;168751            1;814   52;143188  21;467  46;191332  48;699  95;123399                                                8.00
# 355030896000244;3;"Regi�o Sudeste";35;"S�o Paul... 87;2 49;692  5;239941             27;812  93;182516  2;439   33;194034  99;702  1;124952                                                38.00
# 355030896000245;3;"Regi�o Sudeste";35;"S�o Paul... 9;2  54;630  06;329705            22;843  31;260395  9;347   6;228162   66;767  5;181129                                                99.00
# 355030896000246;3;"Regi�o Sudeste";35;"S�o Paul... 29;4 21;597  37;349101;908;244391 67;397  76;436942  16;854  2;550319   43      NaN                                                       NaN
# 355030896000247;3;"Regi�o Sudeste";35;"S�o Paul... 77;3 28;630  13;183904            29;790  88;102860  11;431  82;186963  45;728  7;98771                                                 74.00
#
# [18363 rows x 1 columns]

# %% [markdown]
# # **DESAFIOS AULA 3**
#
#
#
# 1.   Tentar vincular dados do IBGE com os dados de imóveis (Thiago);
# 2.   Tratar os outliers e comparar os resultados (Vivian);
# 3.   Agrupar por mais de uma categoria e realizar as análises (Vivian);
# 4.   Organize o colab para deixar com cara de projeto (Thiago).

# %% [markdown]
# # **Desafio 1 - Tentar vincular dados do IBGE com os dados de imóveis**

# %%
ibge_url = "https://gist.githubusercontent.com/tgcsantos/85f8c7b0a2edbc3e27fcad619b37d886/raw/a4954781e6bca9cb804062a3eea0b3b84679daf4/Basico_SP1.csv"
ibge_dados = pd.read_csv(ibge_url, sep=';', encoding='UTF-8')
ibge_dados = ibge_dados.replace('�','a', regex=True)
ibge_dados = ibge_dados.dropna(axis=1)
ibge_dados.rename(columns = {'Nome_do_distrito':'Bairro'},inplace = True)
ibge_dados
# Out:
#              Cod_setor  Cod_Grandes Regi�es Nome_Grande_Regiao  Cod_UF  \
# 0      355030801000001                    3     Regiao Sudeste      35
# 1      355030801000002                    3     Regiao Sudeste      35
# 2      355030801000003                    3     Regiao Sudeste      35
# 3      355030801000004                    3     Regiao Sudeste      35
# 4      355030801000005                    3     Regiao Sudeste      35
# ...                ...                  ...                ...     ...
# 18358  355030896000243                    3     Regiao Sudeste      35
# 18359  355030896000244                    3     Regiao Sudeste      35
# 18360  355030896000245                    3     Regiao Sudeste      35
# 18361  355030896000246                    3     Regiao Sudeste      35
# 18362  355030896000247                    3     Regiao Sudeste      35
#
#       Nome_da_UF   Cod_meso                Nome_da_meso  Cod_micro  \
# 0       Sao Paulo      3515  Metropolitana de Sao Paulo      35061
# 1       Sao Paulo      3515  Metropolitana de Sao Paulo      35061
# 2       Sao Paulo      3515  Metropolitana de Sao Paulo      35061
# 3       Sao Paulo      3515  Metropolitana de Sao Paulo      35061
# 4       Sao Paulo      3515  Metropolitana de Sao Paulo      35061
# ...           ...       ...                         ...        ...
# 18358   Sao Paulo      3515  Metropolitana de Sao Paulo      35061
# 18359   Sao Paulo      3515  Metropolitana de Sao Paulo      35061
# 18360   Sao Paulo      3515  Metropolitana de Sao Paulo      35061
# 18361   Sao Paulo      3515  Metropolitana de Sao Paulo      35061
# 18362   Sao Paulo      3515  Metropolitana de Sao Paulo      35061
#
#       Nome_da_micro  Cod_RM  ... Cod_distrito     Bairro Cod_subdistrito  \
# 0         Sao Paulo      20  ...    355030801  aGUA RASA     35503080100
# 1         Sao Paulo      20  ...    355030801  aGUA RASA     35503080100
# 2         Sao Paulo      20  ...    355030801  aGUA RASA     35503080100
# 3         Sao Paulo      20  ...    355030801  aGUA RASA     35503080100
# 4         Sao Paulo      20  ...    355030801  aGUA RASA     35503080100
# ...             ...     ...  ...          ...        ...             ...
# 18358     Sao Paulo      20  ...    355030896    LAJEADO     35503089600
# 18359     Sao Paulo      20  ...    355030896    LAJEADO     35503089600
# 18360     Sao Paulo      20  ...    355030896    LAJEADO     35503089600
# 18361     Sao Paulo      20  ...    355030896    LAJEADO     35503089600
# 18362     Sao Paulo      20  ...    355030896    LAJEADO     35503089600
#
#        Nome_do_subdistrito  Cod_bairro                Nome_do_bairro  \
# 0                aGUA RASA  3550308000  SaO PAULO (todos os setores)
# 1                aGUA RASA  3550308000  SaO PAULO (todos os setores)
# 2                aGUA RASA  3550308000  SaO PAULO (todos os setores)
# 3                aGUA RASA  3550308000  SaO PAULO (todos os setores)
# 4                aGUA RASA  3550308000  SaO PAULO (todos os setores)
# ...                    ...         ...                           ...
# 18358              LAJEADO  3550308000  SaO PAULO (todos os setores)
# 18359              LAJEADO  3550308000  SaO PAULO (todos os setores)
# 18360              LAJEADO  3550308000  SaO PAULO (todos os setores)
# 18361              LAJEADO  3550308000  SaO PAULO (todos os setores)
# 18362              LAJEADO  3550308000  SaO PAULO (todos os setores)
#
#       Situacao_setor  Tipo_setor     V009        V010
# 0                  1           0  1227,41  4285771,99
# 1                  1           0  1045,78  2572133,32
# 2                  1           0   902,97  2735492,52
# 3                  1           0   869,09  2122409,02
# 4                  1           0   917,71  1570047,75
# ...              ...         ...      ...         ...
# 18358              1           1   467,46   191332,48
# 18359              1           1   439,33   194034,99
# 18360              1           1    347,6   228162,66
# 18361              1           0   397,76   436942,16
# 18362              1           1   431,82   186963,45
#
# [18363 rows x 23 columns]

# %%
dados["Bairro"] = dados['Bairro'].str.upper()
dados["Bairro"]
# Out:
# 0         PLANALTO PAULISTA
# 1        JARDIM DOS ESTADOS
# 2           JARDIM REIMBERG
# 3            JARDIM MORUMBI
# 4                     MOOCA
#                 ...
# 10003            VILA SOFIA
# 10004       BOSQUE DA SAÚDE
# 10005         VILA DA SAÚDE
# 10006         VILA ORATÓRIO
# 10007           VILA ALPINA
# Name: Bairro, Length: 10008, dtype: object

# %%
ibge_dados['Bairro'] = ibge_dados['Bairro'].str.upper()
ibge_dados['Bairro']
# Out:
# 0        AGUA RASA
# 1        AGUA RASA
# 2        AGUA RASA
# 3        AGUA RASA
# 4        AGUA RASA
#            ...
# 18358      LAJEADO
# 18359      LAJEADO
# 18360      LAJEADO
# 18361      LAJEADO
# 18362      LAJEADO
# Name: Bairro, Length: 18363, dtype: object

# %%
merge_dados = dados.merge(ibge_dados, on ='Bairro', how = 'left')
merge_dados.dropna(axis=0).sample(5)
# Out:
#                                           Rua       Bairro     Cidade  \
# 267801              Rua Duque de Caxias, 298   SANTO AMARO  São Paulo
# 165221                            Rua Bamboré     IPIRANGA  São Paulo
# 5499                           Rua Guararapes         LAPA  São Paulo
# 37626                 Rua Teixeira de Freitas  SANTO AMARO  São Paulo
# 12710   Rua General Euclides Figueiredo, 442       MORUMBI  São Paulo
#
#         Metragem  Quartos  Banheiros  Vagas  \
# 267801      7126        7          2     20
# 165221       400        3          4      6
# 5499         515        3          5      8
# 37626        800        6         10      8
# 12710        550        4          7      3
#
#                                         Valor Moeda Valor_anuncio  ...  \
# 267801  R$ 80.000\n                      /Mês    R$        80.000  ...
# 165221   R$ 7.000\n                      /Mês    R$         7.000  ...
# 5499    R$ 30.000\n                      /Mês    R$        30.000  ...
# 37626   R$ 55.000\n                      /Mês    R$        55.000  ...
# 12710   R$ 13.000\n                      /Mês    R$        13.000  ...
#
#        Nome_do_municipio  Cod_distrito  Cod_subdistrito Nome_do_subdistrito  \
# 267801         SaO PAULO  355030871.00   35503087100.00         SANTO AMARO
# 165221         SaO PAULO  355030834.00   35503083400.00            IPIRANGA
# 5499           SaO PAULO  355030848.00   35503084800.00                LAPA
# 37626          SaO PAULO  355030871.00   35503087100.00         SANTO AMARO
# 12710          SaO PAULO  355030854.00   35503085400.00             MORUMBI
#
#           Cod_bairro                Nome_do_bairro  Situacao_setor Tipo_setor  \
# 267801 3550308000.00  SaO PAULO (todos os setores)            1.00       0.00
# 165221 3550308000.00  SaO PAULO (todos os setores)            1.00       0.00
# 5499   3550308000.00  SaO PAULO (todos os setores)            1.00       0.00
# 37626  3550308000.00  SaO PAULO (todos os setores)            1.00       0.00
# 12710  3550308000.00  SaO PAULO (todos os setores)            1.00       0.00
#
#            V009          V010
# 267801  4315,46    40493693,9
# 165221  1353,19    4382325,38
# 5499    1888,92    8731683,66
# 37626   3415,94   42315674,65
# 12710   8348,87  311876258,94
#
# [5 rows x 33 columns]

# %% [markdown]
# *Solução encontrada graças aos excertos de @letíciajsx (https://github.com/leticiajsx/imersaoDados4Alura/blob/main/Imersao_dados_4_aula03.ipynb)*

# %% [markdown]
# # **Desafio 2 - Tratar os outliers e comparar os resultados**

# %%
plt.figure(figsize=(10, 8))
ax = sns.boxplot(data = dados_vendas.query("Bairro in @top_bairros & Metragem < 30000"), x="Bairro", y="Metragem")
ax.tick_params(axis='x', rotation=45)
plt.show()

# %%
dados_vendas.Metragem.describe()
# Out:
# count     9156.00
# mean       434.42
# std       7856.42
# min         10.00
# 25%        168.00
# 50%        276.00
# 75%        450.00
# max     750000.00
# Name: Metragem, dtype: float64

# %%
plt.figure(figsize=(10, 8))
ax = sns.boxplot(data = dados_vendas.query("Bairro in @top_bairros & Metragem > 168 and Metragem < 450"), x="Bairro", y="Metragem")
ax.tick_params(axis='x', rotation=45)
plt.show()

# %% [markdown]
# *Solução encontrada graças aos excertos de @astrostark (https://github.com/astrostark/AluraImersaoDados4/blob/main/Aula3.ipynb).*

# %% [markdown]
# # **Desafio 3 - Agrupar por mais de uma categoria e realizar as análises**

# %%
dados_agrupados_metragem = dados.groupby(['Metragem']).mean()
dados_agrupados_metragem = dados_agrupados_metragem.reset_index()
dados_agrupados_metragem = dados_agrupados_metragem.nlargest(n=10, columns=['Metragem'])
dados_agrupados_metragem
# Out:
#      Metragem  Quartos  Banheiros  Vagas
# 915    750000     5.00       9.00   6.00
# 914     37000     4.00       2.00   4.00
# 913     35677     3.00       3.00   4.00
# 912      7126     7.00       2.00  20.00
# 911      2850     3.00       3.00  10.00
# 910      2505     3.00       7.00  12.00
# 909      2500     3.00       7.00  12.00
# 908      2200     6.00       7.67  13.00
# 907      2165     3.00       4.00  10.00
# 906      2160     3.00       4.00  10.00

# %%
sns.catplot(x="Metragem", y='Quartos', kind="bar", palette="ch:.75", data=dados_agrupados_metragem, height=7, aspect=2)

# %% [markdown]
# É possível concluir que, em média, os imóveis com maior metragem possuem 3 ou mais quartos.

# %% [markdown]
# *Solução encontrada graças aos excertos de @letíciajsx (https://github.com/leticiajsx/imersaoDados4Alura/blob/main/Imersao_dados_4_aula03.ipynb)*

# %% [markdown]
# # **Desafio 4 - Organize o colab para deixar com cara de projeto**

# %% [markdown]
# *(Obs. Será realizado no fim do projeto).*
